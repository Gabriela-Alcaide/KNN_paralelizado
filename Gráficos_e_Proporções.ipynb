# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriela-Alcaide/KNN_paralelizado/blob/main/Gr%C3%A1ficos_e_Propor%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports e dados

# %%
import matplotlib.pyplot as plt

# %%
arquivos_nomes = ["dados_xtest_10", "dados_xtest_30", "dados_xtest_50", "dados_xtest_100", "dados_xtest_1000", "dados_xtest_100000", "dados_xtest_1000000", "dados_xtest_10000000"]

# %%
sequenciais = [
    0.00009070010855793953,
    0.00037720007821917534,
    0.00071680033579468727,
    0.00097779976204037666,
    0.00918219983577728270,
    0.78948320029303432000,
    7.90662970021367070000,
    93.71258029993623500000,
]

# %% [markdown]
# # Gráfico - Sequencial

# %%
# Criando o gráfico de linha
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Tempos - Sequencial")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# # Paralelizando tudo

# %%
# 04 threads - paralelizando tudo.

tempos = [0.00064759980887174606, 0.00037180003710091114, 0.00112510006874799728, 0.00084380013868212700, 0.00774720008485019207, 0.56472779996693134308, 5.79259230010211467743, 72.69645650009624660015]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Totalmente Paralelizado - 04 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 08 threads - paralelizando tudo.

tempos = [0.00041349999992235098, 0.00066650000007939525, 0.00067429999944579322, 0.00211390000004030298, 0.01354539999920234550, 0.48423640000146406237, 5.17411450000145123340, 52.54615150000063295010]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Totalmente Paralelizado - 08 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 16 threads - paralelizando tudo.

tempos = [0.00038300000051094685, 0.00056880000011005905, 0.00085620000027120113, 0.00122900000133085996, 0.00628190000134054571, 0.56292329999996582046, 5.80479000000013911631, 75.54542720000063127372]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Totalmente Paralelizado - 16 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# # Sem paralelizar "k-menores" e "calcular distancias"

# %%
# 04 threads - sem paralelizar "k-menores" e "calcular-distancias"

tempos = [0.00072349999936704990, 0.00030520000109390821, 0.00034549999872979242, 0.00047509999967587646, 0.00314789999902131967, 0.18858079999881738331, 2.30233149999912711792, 25.63123689999883936252]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização sem 'k-menores' e 'calcular_distancias' - 04 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 08 threads - sem paralelizar "k-menores" e "calcular-distancias"

tempos = [0.00052190000042173779, 0.00024910000001909793, 0.00035249999973530066, 0.00051639999992403318, 0.00313460000006671180, 0.14681759999984933529, 1.51825980000012350501, 18.02234399999997549457]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização sem 'k-menores' e 'calcular_distancias' - 08 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 12 threads - sem paralelizar "k-menores" e "calcular-distancias"

tempos = [0.00034439999990354409, 0.00026900000011664815, 0.00044189999971422367, 0.00044100000013713725, 0.00320610000017040875, 0.15716309999970690114, 1.54966229999990900978, 16.27151980000007824856]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização sem 'k-menores' e 'calcular_distancias' - 12 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 16 threads - sem paralelizar "k-menores" e "calcular-distancias"

tempos = [0.00022929999977350235, 0.00027380000028642826, 0.00038909999966563191, 0.00064090000023497851, 0.00264749999996638508, 0.16219799999998940621, 1.54589549999991504592, 16.43502630000011777156]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização sem 'k-menores' e 'calcular_distancias' - 16 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 24 threads - sem paralelizar "k-menores" e "calcular-distancias"

tempos = [0.00054280000040307641, 0.00036679999993793899, 0.00030460000016319100, 0.00056119999953807564, 0.00546239999948738841, 0.15387629999986529583, 1.51147080000009736978, 15.75786790000074688578]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização sem 'k-menores' e 'calcular_distancias' - 24 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 32 threads - sem paralelizar "k-menores" e "calcular-distancias"

tempos = [0.00032100000044010812, 0.00044069999967177864, 0.00041460000011284137, 0.00066979999974137172, 0.00292710000030638184, 0.15876769999977113912, 1.49810390000038751168, 16.98036199999933160143]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização sem 'k-menores' e 'calcular_distancias' - 32 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# # Proporção de tempo ocupada por cada tarefa - Sequencial

# %%
# Arquivo 10.

total_arquivo_10 = 0.00049690000014379621

popular_matriz_teste_10 = 0.00000160001218318939 / total_arquivo_10
calcular_distancias_10 = 0.00007100001676008105 / total_arquivo_10
encontrar_k_menores_10 = 0.00001970006269402802 / total_arquivo_10
calcular_valores_y_teste_10 = 0.00000099997851066291 / total_arquivo_10

# %%
print(popular_matriz_teste_10)
print(calcular_distancias_10)
print(encontrar_k_menores_10)
print(calcular_valores_y_teste_10)
# Out:
# 0.0032199882928685207
# 0.1428859262216434
# 0.039645930143544145
# 0.0020124341122429654

# %%
# Arquivo 30.

total_arquivo_30 = 0.00079240000923164189

popular_matriz_teste_30 = 0.00000359999830834568 / total_arquivo_30
calcular_distancias_30 = 0.00029610001365654171 / total_arquivo_30
encontrar_k_menores_30 = 0.00008590001380071044 / total_arquivo_30
calcular_valores_y_teste_30 = 0.00000310002360492945 / total_arquivo_30

# %%
print(popular_matriz_teste_30)
print(calcular_distancias_30)
print(encontrar_k_menores_30)
print(calcular_valores_y_teste_30)
# Out:
# 0.004543157832414026
# 0.3736749245417827
# 0.10840486219075665
# 0.0039121953165238066

# %%
# Arquivo 50.

total_arquivo_50 = 0.00114900001790374520

popular_matriz_teste_50 = 0.00000550001277588308 / total_arquivo_50
calcular_distancias_50 = 0.00048070008051581681 / total_arquivo_50
encontrar_k_menores_50 = 0.00014469993766397238 / total_arquivo_50
calcular_valores_y_teste_50 = 0.00000579995685257018 / total_arquivo_50

# %%
print(popular_matriz_teste_50)
print(calcular_distancias_50)
print(encontrar_k_menores_50)
print(calcular_valores_y_teste_50)
# Out:
# 0.00478678214985357
# 0.4183638581597362
# 0.12593553995583512
# 0.005047830080239441

# %%
# Arquivo 100.

total_arquivo_100 = 0.00207409998984076080

popular_matriz_teste_100 = 0.00000800000270828605 / total_arquivo_100
calcular_distancias_100 = 0.00104250010917894540 / total_arquivo_100
encontrar_k_menores_100 = 0.00038540002424269915 / total_arquivo_100
calcular_valores_y_teste_100 = 0.00000949998502619565 / total_arquivo_100

# %%
print(popular_matriz_teste_100)
print(calcular_distancias_100)
print(encontrar_k_menores_100)
print(calcular_valores_y_teste_100)
# Out:
# 0.0038570959681168753
# 0.5026277008269903
# 0.18581554704712586
# 0.004580292692120891

# %%
# Arquivo 1000.

total_arquivo_1000 = 0.01695789999212138400

popular_matriz_teste_1000 = 0.00010850001126527786 / total_arquivo_1000
calcular_distancias_1000 = 0.01057900069281458900 / total_arquivo_1000
encontrar_k_menores_1000 = 0.00326470038271509110 / total_arquivo_1000
calcular_valores_y_teste_1000 = 0.00009839996346272528 / total_arquivo_1000

# %%
print(popular_matriz_teste_1000)
print(calcular_distancias_1000)
print(encontrar_k_menores_1000)
print(calcular_valores_y_teste_1000)
# Out:
# 0.006398198557350074
# 0.6238390778179832
# 0.19251796414838312
# 0.005802603123526012

# %%
# Arquivo 100000.

total_arquivo_100000 = 1.21345860001747500000

popular_matriz_teste_100000 = 0.00751070000114850700 / total_arquivo_100000
calcular_distancias_100000 = 0.85243020515190437000 / total_arquivo_100000
encontrar_k_menores_100000 = 0.29178899541147985000 / total_arquivo_100000
calcular_valores_y_teste_100000 = 0.00711399898864328860 / total_arquivo_100000

# %%
print(popular_matriz_teste_100000)
print(calcular_distancias_100000)
print(encontrar_k_menores_100000)
print(calcular_valores_y_teste_100000)
# Out:
# 0.0061894983488026255
# 0.7024798416193421
# 0.24046061019904413
# 0.005862580716425629

# %%
# Arquivo 1000000.

total_arquivo_1000000 = 10.50805189998936800000

popular_matriz_teste_1000000 = 0.07608289999188855300 / total_arquivo_1000000
calcular_distancias_1000000 = 7.27421749519999140000 / total_arquivo_1000000
encontrar_k_menores_1000000 = 2.64178469593753110000 / total_arquivo_1000000
calcular_valores_y_teste_1000000 = 0.06493570207385346300 / total_arquivo_1000000

# %%
print(popular_matriz_teste_1000000)
print(calcular_distancias_1000000)
print(encontrar_k_menores_1000000)
print(calcular_valores_y_teste_1000000)
# Out:
# 0.007240438162659392
# 0.6922517669718924
# 0.2514057525677242
# 0.0061796137563727834

# %%
# 10000000.

total_arquivo_10000000 = 114.87154680001549000000

popular_matriz_teste_10000000 = 1.06399769999552520000 / total_arquivo_10000000
calcular_distancias_10000000 = 79.39062234593438900000 / total_arquivo_10000000
encontrar_k_menores_10000000 = 28.61500584526220300000 / total_arquivo_10000000
calcular_valores_y_teste_10000000 = 0.81881421632715501000 / total_arquivo_10000000

# %%
print(popular_matriz_teste_10000000)
print(calcular_distancias_10000000)
print(encontrar_k_menores_10000000)
print(calcular_valores_y_teste_10000000)
# Out:
# 0.00926249998050328
# 0.6911252138368844
# 0.24910438348217961
# 0.007128085580258283

# %% [markdown]
# # Paralelizar APENAS o for da função "criar_yTeste"

# %%
# 04 threads.

tempos = [0.00124839999989490025, 0.00022020000324118882, 0.00042539999776636250, 0.00037339999835239723, 0.00301570000010542572, 0.19685150000077555887, 2.18983519999892450869, 25.66532850000294274651]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização APENAS for de 'criar_YTeste' - 04 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 08 threads.

tempos = [0.00231730000086827204, 0.00027509999927133322, 0.00031559999843011610, 0.00039699999979347922, 0.00320090000241179951, 0.14803930000198306516, 1.61393150000003515743, 17.36090420000255107880]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização APENAS for de 'criar_YTeste' - 08 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 12 threads.

tempos = [0.00286319999941042624, 0.00023690000307396986, 0.00019569999858504161, 0.00036519999775919132, 0.00229069999841158278, 0.15586790000088512897, 1.51826700000310665928, 16.26589660000172443688]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização APENAS for de 'criar_YTeste' - 12 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 16 threads.

tempos = [0.00289319999865256250, 0.00014000000010128133, 0.00033040000198525377, 0.00053609999667969532, 0.00262880000082077459, 0.15579979999893112108, 1.58443890000125975348, 17.24257109999962267466]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização APENAS for de 'criar_YTeste' - 16 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 24 threads.

tempos = [0.00433619999967049807, 0.00027469999986351468, 0.00049530000251252204, 0.00076429999899119139, 0.00207819999923231080, 0.15792259999943780713, 1.55252830000245012343, 16.29802000000199768692]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização APENAS for de 'criar_YTeste' - 24 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# 32 threads

tempos = [0.00308730000324430875, 0.00037230000089039095, 0.00031680000029155053, 0.00036069999987375923, 0.00215000000025611371, 0.14980689999720198102, 1.60976790000131586567, 16.55974199999764095992]

# Criando o gráfico de linha
plt.plot(arquivos_nomes, tempos, label="Paralelizado", color="blue", marker="o")
plt.plot(arquivos_nomes, sequenciais, label="Sequencial", color="red", marker="s")

# Personalização
plt.title("Paralelização APENAS for de 'criar_YTeste' - 32 threads")
plt.xlabel("Arquivos")
plt.ylabel("Tempo (segundos) - Log")

plt.xticks(rotation=45, ha='right')
plt.yscale("log")

plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Exibindo o gráfico
plt.tight_layout()
plt.show()
